# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt

# %%
# !pip install opendatasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opendatasets in c:\users\asus\appdata\roaming\python\python39\site-packages (0.1.22)
# Requirement already satisfied: click in c:\users\asus\appdata\roaming\python\python39\site-packages (from opendatasets) (8.0.3)
# Requirement already satisfied: kaggle in c:\users\asus\appdata\roaming\python\python39\site-packages (from opendatasets) (1.5.13)
# Requirement already satisfied: tqdm in c:\users\asus\appdata\roaming\python\python39\site-packages (from opendatasets) (4.62.3)
# Requirement already satisfied: colorama in c:\users\asus\appdata\roaming\python\python39\site-packages (from click->opendatasets) (0.4.4)
# Requirement already satisfied: six>=1.10 in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi in c:\users\asus\appdata\roaming\python\python39\site-packages (from kaggle->opendatasets) (2021.10.8)
# Requirement already satisfied: urllib3 in c:\users\asus\appdata\roaming\python\python39\site-packages (from kaggle->opendatasets) (1.26.7)
# Requirement already satisfied: python-slugify in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (5.0.2)
# Requirement already satisfied: requests in c:\users\asus\appdata\roaming\python\python39\site-packages (from kaggle->opendatasets) (2.26.0)
# Requirement already satisfied: python-dateutil in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: text-unidecode>=1.3 in c:\programdata\anaconda3\lib\site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\roaming\python\python39\site-packages (from requests->kaggle->opendatasets) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asus\appdata\roaming\python\python39\site-packages (from requests->kaggle->opendatasets) (2.0.9)

# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/kkhandekar/electric-vehicles-india")
# Out:
# Skipping, found downloaded files in ".\electric-vehicles-india" (use force=True to force download)

# %%
df=pd.read_csv("electric-vehicles-india/EVIndia.csv")
df
# Out:
#                       Car                  Style               Range  \
# 0           Tata Nexon EV            Compact SUV  312 Km/Full Charge
# 1           Tata Tigor EV       Subcompact Sedan  306 Km/Full Charge
# 2       Tata Nexon EV Max            Compact SUV  437 Km/Full Charge
# 3                MG ZS EV            Compact SUV  419 Km/Full Charge
# 4   Hyundai Kona Electric            Compact SUV  452 Km/Full Charge
# 5           Jaguar I-Pace  Premium Midsize Sedan  470 Km/Full Charge
# 6          Audi E-Tron GT          Premium Coupe  388 Km/Full Charge
# 7                  BYD E6         Subcompact MPV  415 Km/Full Charge
# 8       Mercedes-Benz EQC            Compact SUV  471 Km/Full Charge
# 9                  BMW iX   Premium Fullsize SUV  425 Km/Full Charge
# 10         Porsche Taycan   Premium Sports Sedan                  na
# 11            Audi E-Tron            Compact SUV  400 Km/Full Charge
#
#    Transmission VehicleType         PriceRange   Capacity BootSpace  \
# 0     Automatic    Electric   ₹ 13.99 - 17.4 L  5 Seater      350 L
# 1     Automatic    Electric  ₹ 12.49 - 13.64 L  5 Seater      316 L
# 2     Automatic    Electric  ₹ 17.74 - 19.24 L  5 Seater      350 L
# 3     Automatic    Electric  ₹ 21.99 - 25.88 L  5 Seater      448 L
# 4     Automatic    Electric  ₹ 23.79 - 23.98 L  5 Seater         na
# 5     Automatic    Electric   ₹ 1.06 - 1.12 Cr  5 Seater      656 L
# 6     Automatic    Electric           ₹ 1.8 Cr  5 Seater      405 L
# 7     Automatic    Electric          ₹ 29.15 L  5 Seater      580 L
# 8     Automatic    Electric             ₹ 1 Cr  5 Seater         na
# 9     Automatic    Electric          ₹ 1.16 Cr  5 Seater         na
# 10    Automatic    Electric           ₹ 1.5 Cr  4 Seater         na
# 11    Automatic    Electric   ₹ 1.01 - 1.19 Cr  5 Seater      660 L
#
#              BaseModel             TopModel
# 0                  XM     Dark XZ Plus LUX
# 1                  XE    XZ Plus Dual Tone
# 2      XZ Plus 3.3 kW   XZ Plus Lux 7.2 kW
# 3              Excite            Exclusive
# 4   Premium Dual Tone                  HSE
# 5                   S         Sportback 55
# 6             Quattro                    na
# 7                 STD                    na
# 8                   na                   na
# 9                   na                   na
# 10                  na                   na
# 11                  na                   na

# %% [markdown]
# ## Preprocessing

# %%
def Preprocess1(df,old_col):
#     old_col=old_col[0]
    df[old_col]=df[old_col].replace("na","0 L")
    bootspace=df[old_col].str.split("L",n=1,expand=True)
    df[old_col+"_new"]=bootspace[0]
    df[old_col+"_new"]=df[old_col+"_new"].astype(int)
    df[old_col+"_new"].mean()
    df[old_col+"_new"]=df[old_col+"_new"].replace(0,df["BootSpace_new"].mean())
    df=pd.DataFrame(df)
    return df

# %%
df=Preprocess1(df,"BootSpace")
df
# Out:
#                       Car                  Style               Range  \
# 0           Tata Nexon EV            Compact SUV  312 Km/Full Charge
# 1           Tata Tigor EV       Subcompact Sedan  306 Km/Full Charge
# 2       Tata Nexon EV Max            Compact SUV  437 Km/Full Charge
# 3                MG ZS EV            Compact SUV  419 Km/Full Charge
# 4   Hyundai Kona Electric            Compact SUV  452 Km/Full Charge
# 5           Jaguar I-Pace  Premium Midsize Sedan  470 Km/Full Charge
# 6          Audi E-Tron GT          Premium Coupe  388 Km/Full Charge
# 7                  BYD E6         Subcompact MPV  415 Km/Full Charge
# 8       Mercedes-Benz EQC            Compact SUV  471 Km/Full Charge
# 9                  BMW iX   Premium Fullsize SUV  425 Km/Full Charge
# 10         Porsche Taycan   Premium Sports Sedan                  na
# 11            Audi E-Tron            Compact SUV  400 Km/Full Charge
#
#    Transmission VehicleType         PriceRange   Capacity BootSpace  \
# 0     Automatic    Electric   ₹ 13.99 - 17.4 L  5 Seater      350 L
# 1     Automatic    Electric  ₹ 12.49 - 13.64 L  5 Seater      316 L
# 2     Automatic    Electric  ₹ 17.74 - 19.24 L  5 Seater      350 L
# 3     Automatic    Electric  ₹ 21.99 - 25.88 L  5 Seater      448 L
# 4     Automatic    Electric  ₹ 23.79 - 23.98 L  5 Seater        0 L
# 5     Automatic    Electric   ₹ 1.06 - 1.12 Cr  5 Seater      656 L
# 6     Automatic    Electric           ₹ 1.8 Cr  5 Seater      405 L
# 7     Automatic    Electric          ₹ 29.15 L  5 Seater      580 L
# 8     Automatic    Electric             ₹ 1 Cr  5 Seater        0 L
# 9     Automatic    Electric          ₹ 1.16 Cr  5 Seater        0 L
# 10    Automatic    Electric           ₹ 1.5 Cr  4 Seater        0 L
# 11    Automatic    Electric   ₹ 1.01 - 1.19 Cr  5 Seater      660 L
#
#              BaseModel             TopModel  BootSpace_new
# 0                  XM     Dark XZ Plus LUX          350.00
# 1                  XE    XZ Plus Dual Tone          316.00
# 2      XZ Plus 3.3 kW   XZ Plus Lux 7.2 kW          350.00
# 3              Excite            Exclusive          448.00
# 4   Premium Dual Tone                  HSE          313.75
# 5                   S         Sportback 55          656.00
# 6             Quattro                    na         405.00
# 7                 STD                    na         580.00
# 8                   na                   na         313.75
# 9                   na                   na         313.75
# 10                  na                   na         313.75
# 11                  na                   na         660.00

# %%
df['PriceRange']=df['PriceRange'].replace(['₹ 1.8 Cr','₹ 1.16 Cr','₹ 1.06 - 1.12 Cr','₹ 1 Cr','₹ 1.5 Cr','₹ 1.01 - 1.19 Cr'],['₹ 180 L','₹ 116 L','₹ 106 - 112 L','₹ 100 L','₹ 150 L','₹ 101 - 119 L'])
df
# Out:
#                       Car                  Style               Range  \
# 0           Tata Nexon EV            Compact SUV  312 Km/Full Charge
# 1           Tata Tigor EV       Subcompact Sedan  306 Km/Full Charge
# 2       Tata Nexon EV Max            Compact SUV  437 Km/Full Charge
# 3                MG ZS EV            Compact SUV  419 Km/Full Charge
# 4   Hyundai Kona Electric            Compact SUV  452 Km/Full Charge
# 5           Jaguar I-Pace  Premium Midsize Sedan  470 Km/Full Charge
# 6          Audi E-Tron GT          Premium Coupe  388 Km/Full Charge
# 7                  BYD E6         Subcompact MPV  415 Km/Full Charge
# 8       Mercedes-Benz EQC            Compact SUV  471 Km/Full Charge
# 9                  BMW iX   Premium Fullsize SUV  425 Km/Full Charge
# 10         Porsche Taycan   Premium Sports Sedan                  na
# 11            Audi E-Tron            Compact SUV  400 Km/Full Charge
#
#    Transmission VehicleType         PriceRange   Capacity BootSpace  \
# 0     Automatic    Electric   ₹ 13.99 - 17.4 L  5 Seater      350 L
# 1     Automatic    Electric  ₹ 12.49 - 13.64 L  5 Seater      316 L
# 2     Automatic    Electric  ₹ 17.74 - 19.24 L  5 Seater      350 L
# 3     Automatic    Electric  ₹ 21.99 - 25.88 L  5 Seater      448 L
# 4     Automatic    Electric  ₹ 23.79 - 23.98 L  5 Seater        0 L
# 5     Automatic    Electric      ₹ 106 - 112 L  5 Seater      656 L
# 6     Automatic    Electric            ₹ 180 L  5 Seater      405 L
# 7     Automatic    Electric          ₹ 29.15 L  5 Seater      580 L
# 8     Automatic    Electric            ₹ 100 L  5 Seater        0 L
# 9     Automatic    Electric            ₹ 116 L  5 Seater        0 L
# 10    Automatic    Electric            ₹ 150 L  4 Seater        0 L
# 11    Automatic    Electric      ₹ 101 - 119 L  5 Seater      660 L
#
#              BaseModel             TopModel  BootSpace_new
# 0                  XM     Dark XZ Plus LUX          350.00
# 1                  XE    XZ Plus Dual Tone          316.00
# 2      XZ Plus 3.3 kW   XZ Plus Lux 7.2 kW          350.00
# 3              Excite            Exclusive          448.00
# 4   Premium Dual Tone                  HSE          313.75
# 5                   S         Sportback 55          656.00
# 6             Quattro                    na         405.00
# 7                 STD                    na         580.00
# 8                   na                   na         313.75
# 9                   na                   na         313.75
# 10                  na                   na         313.75
# 11                  na                   na         660.00

# %%
price=df['PriceRange'].str.split('₹',n=1,expand=True)
price=price[1].str.split('-',n=1,expand=True)
st_price,fi_price=price[0],price[1]
st_price=st_price.str.split('L',n=1,expand=True)
df['StartingPrice(in Lakh)']=st_price[0].str.split('L',n=1,expand=True)
fi_price=fi_price.str.split('L',n=1,expand=True)
df['FinalPrice(in Lakh)']=fi_price[0].str.split('L',n=1,expand=True)
df['StartingPrice(in Lakh)']=df['StartingPrice(in Lakh)'].astype(float)
df['FinalPrice(in Lakh)']=df['FinalPrice(in Lakh)'].astype(float)

# %%
df['Range']=df['Range'].replace('na','0 Km/Full Charge')
df[['Range','Unit']]=df['Range'].str.split(' ',n=1,expand=True)
df=df.drop(['Unit'],axis=1)
# df['Range']=df['Range'].replace("na",0)
df['Range']=df['Range'].astype(int)

# %%
df.columns=['Car', 'Style', 'Range(per Km)', 'Transmission', 'VehicleType', 'PriceRange',
       'Capacity', 'BootSpace', 'BaseModel', 'TopModel', 'BootSpace_new',
       'StartingPrice(in Lakh)', 'FinalPrice(in Lakh)']

# %%
df
# Out:
#                       Car                  Style  Range(per Km) Transmission  \
# 0           Tata Nexon EV            Compact SUV            312    Automatic
# 1           Tata Tigor EV       Subcompact Sedan            306    Automatic
# 2       Tata Nexon EV Max            Compact SUV            437    Automatic
# 3                MG ZS EV            Compact SUV            419    Automatic
# 4   Hyundai Kona Electric            Compact SUV            452    Automatic
# 5           Jaguar I-Pace  Premium Midsize Sedan            470    Automatic
# 6          Audi E-Tron GT          Premium Coupe            388    Automatic
# 7                  BYD E6         Subcompact MPV            415    Automatic
# 8       Mercedes-Benz EQC            Compact SUV            471    Automatic
# 9                  BMW iX   Premium Fullsize SUV            425    Automatic
# 10         Porsche Taycan   Premium Sports Sedan              0    Automatic
# 11            Audi E-Tron            Compact SUV            400    Automatic
#
#    VehicleType         PriceRange   Capacity BootSpace           BaseModel  \
# 0     Electric   ₹ 13.99 - 17.4 L  5 Seater      350 L                 XM
# 1     Electric  ₹ 12.49 - 13.64 L  5 Seater      316 L                 XE
# 2     Electric  ₹ 17.74 - 19.24 L  5 Seater      350 L     XZ Plus 3.3 kW
# 3     Electric  ₹ 21.99 - 25.88 L  5 Seater      448 L             Excite
# 4     Electric  ₹ 23.79 - 23.98 L  5 Seater        0 L  Premium Dual Tone
# 5     Electric      ₹ 106 - 112 L  5 Seater      656 L                  S
# 6     Electric            ₹ 180 L  5 Seater      405 L            Quattro
# 7     Electric          ₹ 29.15 L  5 Seater      580 L                STD
# 8     Electric            ₹ 100 L  5 Seater        0 L                  na
# 9     Electric            ₹ 116 L  5 Seater        0 L                  na
# 10    Electric            ₹ 150 L  4 Seater        0 L                  na
# 11    Electric      ₹ 101 - 119 L  5 Seater      660 L                  na
#
#                TopModel  BootSpace_new  StartingPrice(in Lakh)  \
# 0     Dark XZ Plus LUX          350.00                   13.99
# 1    XZ Plus Dual Tone          316.00                   12.49
# 2   XZ Plus Lux 7.2 kW          350.00                   17.74
# 3            Exclusive          448.00                   21.99
# 4                  HSE          313.75                   23.79
# 5         Sportback 55          656.00                  106.00
# 6                    na         405.00                  180.00
# 7                    na         580.00                   29.15
# 8                    na         313.75                  100.00
# 9                    na         313.75                  116.00
# 10                   na         313.75                  150.00
# 11                   na         660.00                  101.00
#
#     FinalPrice(in Lakh)
# 0                 17.40
# 1                 13.64
# 2                 19.24
# 3                 25.88
# 4                 23.98
# 5                112.00
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11               119.00

# %%
df.drop(['PriceRange','BootSpace'],axis=1,inplace=True)
df
# Out:
#                       Car                  Style  Range(per Km) Transmission  \
# 0           Tata Nexon EV            Compact SUV            312    Automatic
# 1           Tata Tigor EV       Subcompact Sedan            306    Automatic
# 2       Tata Nexon EV Max            Compact SUV            437    Automatic
# 3                MG ZS EV            Compact SUV            419    Automatic
# 4   Hyundai Kona Electric            Compact SUV            452    Automatic
# 5           Jaguar I-Pace  Premium Midsize Sedan            470    Automatic
# 6          Audi E-Tron GT          Premium Coupe            388    Automatic
# 7                  BYD E6         Subcompact MPV            415    Automatic
# 8       Mercedes-Benz EQC            Compact SUV            471    Automatic
# 9                  BMW iX   Premium Fullsize SUV            425    Automatic
# 10         Porsche Taycan   Premium Sports Sedan              0    Automatic
# 11            Audi E-Tron            Compact SUV            400    Automatic
#
#    VehicleType   Capacity           BaseModel             TopModel  \
# 0     Electric  5 Seater                  XM     Dark XZ Plus LUX
# 1     Electric  5 Seater                  XE    XZ Plus Dual Tone
# 2     Electric  5 Seater      XZ Plus 3.3 kW   XZ Plus Lux 7.2 kW
# 3     Electric  5 Seater              Excite            Exclusive
# 4     Electric  5 Seater   Premium Dual Tone                  HSE
# 5     Electric  5 Seater                   S         Sportback 55
# 6     Electric  5 Seater             Quattro                    na
# 7     Electric  5 Seater                 STD                    na
# 8     Electric  5 Seater                   na                   na
# 9     Electric  5 Seater                   na                   na
# 10    Electric  4 Seater                   na                   na
# 11    Electric  5 Seater                   na                   na
#
#     BootSpace_new  StartingPrice(in Lakh)  FinalPrice(in Lakh)
# 0          350.00                   13.99                17.40
# 1          316.00                   12.49                13.64
# 2          350.00                   17.74                19.24
# 3          448.00                   21.99                25.88
# 4          313.75                   23.79                23.98
# 5          656.00                  106.00               112.00
# 6          405.00                  180.00                  NaN
# 7          580.00                   29.15                  NaN
# 8          313.75                  100.00                  NaN
# 9          313.75                  116.00                  NaN
# 10         313.75                  150.00                  NaN
# 11         660.00                  101.00               119.00

# %%
df['FinalPrice(in Lakh)']=df['FinalPrice(in Lakh)'].fillna(0.0)

# %%
type(df['StartingPrice(in Lakh)'][0])
# Out:
# numpy.float64

# %% [markdown]
# ## Visualization

# %%
style=df['Style'].value_counts()
style
# Out:
# Compact SUV              6
# Subcompact Sedan         1
# Premium Midsize Sedan    1
# Premium Coupe            1
# Subcompact MPV           1
# Premium Fullsize SUV     1
# Premium Sports Sedan     1
# Name: Style, dtype: int64

# %%
# con=style.index
# count_plot('Style',df,con,"Style Distribution")

# %%
def count_plot(col,df,con,title):
    plt.figure(figsize=(10,6))
    sb.countplot(y='Style',data=df,order=con,palette='coolwarm_r')
    plt.title(title,{'fontweight':'bold','fontsize':'larger'})
    plt.show()
con=style.index
count_plot('Style',df,con,"Style Distribution")

# %%
range_style=df.groupby('Style')['Range(per Km)'].mean()

# %%
plt.figure(figsize=(18,8))
# sb.barplot(x=range_style.index,y=range_style.values)
# plt.barh(y=range_style.index,width=range_style.values,color='#CD5C5C')
plt.bar(x=range_style.index,height=range_style.values,color='#CD5C5C')
plt.title('Range(per Km) based on style of the vehicles',{'fontweight':'bold','fontsize':'larger'})
plt.xlabel("Style",{'fontweight':'bold','fontsize':'larger'})
plt.ylabel("Range(per Km)",{'fontweight':'bold','fontsize':'larger'})
# Out:
# Text(0, 0.5, 'Range(per Km)')

# %%
df.groupby(['Style','Car'])['StartingPrice(in Lakh)'].max()
# Out:
# Style                  Car
# Compact SUV            Audi E-Tron              101.00
#                        Hyundai Kona Electric     23.79
#                        MG ZS EV                  21.99
#                        Mercedes-Benz EQC        100.00
#                        Tata Nexon EV             13.99
#                        Tata Nexon EV Max         17.74
# Premium Coupe          Audi E-Tron GT           180.00
# Premium Fullsize SUV   BMW iX                   116.00
# Premium Midsize Sedan  Jaguar I-Pace            106.00
# Premium Sports Sedan   Porsche Taycan           150.00
# Subcompact MPV         BYD E6                    29.15
# Subcompact Sedan       Tata Tigor EV             12.49
# Name: StartingPrice(in Lakh), dtype: float64

# %%
start_price=df.groupby('Style')['StartingPrice(in Lakh)'].mean()

# %%
plt.figure(figsize=(18,8))
# sb.barplot(x=range_style.index,y=range_style.values)
# plt.barh(y=range_style.index,width=range_style.values,color='#CD5C5C')
plt.bar(x=start_price.index,height=start_price.values,color='#EE8912')
plt.title('Starting Price(in Lakh) based on style',{'fontweight':'bold','fontsize':'larger'})
plt.xlabel("Style",{'fontweight':'bold','fontsize':'larger'})
plt.ylabel("Starting Price(in Lakh)",{'fontweight':'bold','fontsize':'larger'})
# Out:
# Text(0, 0.5, 'Starting Price(in Lakh)')

# %%
X = list(final_price.index)

start = list(start_price.values)
final = list(final_price.values)
  
X_axis = np.arange(len(X))
plt.figure(figsize=(20,8)) 
plt.bar(X_axis - 0.2, start, 0.4, label = 'Median Starting Price(in Lakh)')
plt.bar(X_axis + 0.2, final, 0.4, label = 'Median Final Price(in Lakh)')
  
plt.xticks(X_axis, X)
plt.xlabel("Style",{'fontweight':'bold','fontsize':'larger'})
plt.ylabel("Price(in Lakh)",{'fontweight':'bold','fontsize':'larger'})
plt.title("Style's median Starting and final price")
plt.legend()
plt.show()

# %% [markdown]
# ## Dataset 2

# %%
data=pd.read_csv('alternative-fuel-stations-in-new-york.csv')
# data.head(10)
data_new=data

# %%
col=['Fuel Type Code', 'Station Name', 'Street Address',
       'Intersection Directions', 'City', 'State', 'ZIP',
       'Station Phone', 'Status Code',
       'Groups With Access Code', 'Access Days Time', 'Cards Accepted',
       'EV Level2 EVSE Num', 'EV DC Fast Count', 'EV Network',
       'EV Network Web', 'Geocode Status', 'Latitude', 'Longitude',
       'Date Last Confirmed', 'ID', 'Updated At', 'Owner Type Code',
       'Open Date',
       'E85 Blender Pump', 'EV Connector Types', 'Country',
       'Groups With Access Code (French)',
       'Access Code', 'Access Detail Code',
       'Facility Type', 'EV Pricing', 'Georeference',
       'NYS Municipal Boundaries 2', 'New York Zip Codes 2', 'Counties 2']

# %%
data_new=data_new[col]

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2697 entries, 0 to 2696
# Data columns (total 36 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Fuel Type Code                    2697 non-null   object
#  1   Station Name                      2697 non-null   object
#  2   Street Address                    2697 non-null   object
#  3   Intersection Directions           134 non-null    object
#  4   City                              2697 non-null   object
#  5   State                             2697 non-null   object
#  6   ZIP                               2697 non-null   int64
#  7   Station Phone                     2673 non-null   object
#  8   Status Code                       2697 non-null   object
#  9   Groups With Access Code           2697 non-null   object
#  10  Access Days Time                  2695 non-null   object
#  11  Cards Accepted                    242 non-null    object
#  12  EV Level2 EVSE Num                2414 non-null   float64
#  13  EV DC Fast Count                  158 non-null    float64
#  14  EV Network                        2558 non-null   object
#  15  EV Network Web                    2388 non-null   object
#  16  Geocode Status                    2697 non-null   object
#  17  Latitude                          2697 non-null   float64
#  18  Longitude                         2697 non-null   float64
#  19  Date Last Confirmed               2697 non-null   object
#  20  ID                                2697 non-null   int64
#  21  Updated At                        2697 non-null   object
#  22  Owner Type Code                   1146 non-null   object
#  23  Open Date                         2679 non-null   object
#  24  E85 Blender Pump                  73 non-null     object
#  25  EV Connector Types                2558 non-null   object
#  26  Country                           2697 non-null   object
#  27  Groups With Access Code (French)  2697 non-null   object
#  28  Access Code                       2697 non-null   object
#  29  Access Detail Code                199 non-null    object
#  30  Facility Type                     998 non-null    object
#  31  EV Pricing                        814 non-null    object
#  32  Georeference                      2697 non-null   object
#  33  NYS Municipal Boundaries 2        2695 non-null   float64
#  34  New York Zip Codes 2              2663 non-null   float64
#  35  Counties 2                        2685 non-null   float64
# dtypes: float64(7), int64(2), object(27)
# memory usage: 758.7+ KB

# %%
data_new.head(5)
# Out:
#   Fuel Type Code                Station Name        Street Address  \
# 0           ELEC            Village of Sodus         14-16 Mill St
# 1           ELEC          DeNooyer Chevrolet           127 Wolf Rd
# 2           ELEC  BRUNSWICK HD BRUNSWICK HD2       1130 Hoosick Rd
# 3           ELEC                AL SIGL WOLK        1600 South Ave
# 4           ELEC   LaGrangeville Tops Market  16 John J Wagner Way
#
#                             Intersection Directions           City State  \
# 0  Enter municipal lot from Main or Gaylord Streets          Sodus    NY
# 1                                               NaN         Albany    NY
# 2                                               NaN           Troy    NY
# 3                                               NaN      Rochester    NY
# 4                                               NaN  LaGrangeville    NY
#
#      ZIP Station Phone Status Code Groups With Access Code  ... Country  \
# 0  14551  315-483-9821           E                  Public  ...      US
# 1  12205           NaN           E     Public - Call ahead  ...      US
# 2  12180  888-758-4389           E                  Public  ...      US
# 3  14620  888-758-4389           E                  Public  ...      US
# 4  12540  855-900-7584           E                  Public  ...      US
#
#   Groups With Access Code (French)  Access Code  Access Detail Code  \
# 0                           Public       public                 NaN
# 1      Public - Appeler à l'avance       public                CALL
# 2                           Public       public                 NaN
# 3                           Public       public                 NaN
# 4                           Public       public                 NaN
#
#   Facility Type EV Pricing                                       Georeference  \
# 0      MUNI_GOV       Free  {'type': 'Point', 'coordinates': [-77.061621, ...
# 1    CAR_DEALER       Free  {'type': 'Point', 'coordinates': [-73.806317, ...
# 2           NaN        NaN  {'type': 'Point', 'coordinates': [-73.60228, 4...
# 3           NaN        NaN  {'type': 'Point', 'coordinates': [-77.61388, 4...
# 4           NaN        NaN  {'type': 'Point', 'coordinates': [-73.795294, ...
#
#    NYS Municipal Boundaries 2  New York Zip Codes 2 Counties 2
# 0                       628.0                 408.0      631.0
# 1                       834.0                  42.0     2030.0
# 2                       130.0                  11.0     2138.0
# 3                       537.0                1679.0     2093.0
# 4                       594.0                 979.0     2040.0
#
# [5 rows x 36 columns]

# %%
data_new['Latitude']
# Out:
# 0       43.235555
# 1       42.717867
# 2       42.758880
# 3       43.123642
# 4       41.667907
#           ...
# 2692    42.909700
# 2693    42.831453
# 2694    43.081539
# 2695    42.901523
# 2696    43.156137
# Name: Latitude, Length: 2697, dtype: float64

# %%
fuel_type_code=data_new['Fuel Type Code'].value_counts().index
idx=data_new['Fuel Type Code'].value_counts().values

# %%
plt.figure(figsize=(10,8))
plt.pie(x=idx,labels=fuel_type_code,explode=[0,0.3,0.4,0.5,1.3],colors=['gold','wheat','yellowgreen','beige','orange'],wedgeprops={'linewidth':1,'edgecolor':'k'},textprops={'fontweight':'bold'},autopct='%1.1f%%')
plt.title("Distribution of types of cars based on Fuel Types",{'fontweight':'bold'})
plt.show()

# %%
conds=data_new['EV Pricing'].value_counts().head(10).index
plt.figure(figsize=(10,8))
sb.countplot(y='EV Pricing',data=data_new,order=conds)
plt.ylabel('Pricing',{'fontweight':'bold'})
plt.xlabel('Count',{'fontweight':'bold'})
plt.title('Range of EV pricing',{'fontweight':'bold'})
plt.show()

# %%
plt.figure(figsize=(10,8))
sb.countplot(y='EV Network',data=data_new)
plt.ylabel('EV Network',{'fontweight':'bold'})
plt.xlabel('No of Cities',{'fontweight':'bold'})
plt.title('Distribution of EV Network',{'fontweight':'bold'})
plt.show()

# %%
data_new.select_dtypes(exclude='object')
# Out:
#         ZIP  EV Level2 EVSE Num  EV DC Fast Count   Latitude  Longitude  \
# 0     14551                 2.0               NaN  43.235555 -77.061621
# 1     12205                 NaN               1.0  42.717867 -73.806317
# 2     12180                 2.0               NaN  42.758880 -73.602280
# 3     14620                 2.0               NaN  43.123642 -77.613880
# 4     12540                 NaN               4.0  41.667907 -73.795294
# ...     ...                 ...               ...        ...        ...
# 2692  12027                 2.0               NaN  42.909700 -73.890620
# 2693  12309                10.0               NaN  42.831453 -73.880977
# 2694  14303                 2.0               NaN  43.081539 -79.070427
# 2695  14203                 2.0               NaN  42.901523 -78.863471
# 2696  14614                 2.0               NaN  43.156137 -77.614096
#
#           ID  NYS Municipal Boundaries 2  New York Zip Codes 2  Counties 2
# 0      92116                       628.0                 408.0       631.0
# 1     117741                       834.0                  42.0      2030.0
# 2     150341                       130.0                  11.0      2138.0
# 3     163584                       537.0                1679.0      2093.0
# 4     164367                       594.0                 979.0      2040.0
# ...      ...                         ...                   ...         ...
# 2692  191537                      1011.0                1153.0      2141.0
# 2693  148041                       107.0                  78.0      2142.0
# 2694  162242                       159.0                 167.0      2131.0
# 2695  169908                       300.0                  34.0      2041.0
# 2696  145450                       537.0                1673.0      2093.0
#
# [2697 rows x 9 columns]

# %%
fig=plt.figure(figsize=(14,10))
corr=data_new.corr('pearson')
sb.heatmap(corr,cmap='RdBu_r',annot=True)
plt.title('heatmap',{'fontweight':'bold'})
plt.show()

# %%
owner_type=data_new['Owner Type Code'].value_counts().index
indx=data_new['Owner Type Code'].value_counts().values

# %%
indx
# Out:
# array([1001,   97,   27,   10,    9,    2], dtype=int64)

# %%
plt.figure(figsize=(18,8))
sb.barplot(x=indx,y=owner_type)
plt.title('Distribution of Owner Type',{'fontweight':'bold','fontsize':'larger'})
plt.xlabel("No of Owners",{'fontweight':'bold','fontsize':'larger'})
plt.ylabel("Type",{'fontweight':'bold','fontsize':'larger'})
# Out:
# Text(0, 0.5, 'Type')
