# %%
import pandas

# %%
import seaborn

# %%
print("Hello Visual Code")
# Out:
# Hello Visual Code

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[0,3,0.1,1]
plt.plot(x,y)
plt.title('Plot X vs Y')
# Out:
# Text(0.5, 1.0, 'Plot X vs Y')
